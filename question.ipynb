# %%
print("hello!")
print("My name is Areesha")
print("i'm 19 year old")
# Out:
# hello!
# My name is Areesha
# i'm 19 year old

# %%
print(3+5)
print(7-2)
print(7*2)
print(7/2)
print(7%2)
# Out:
# 8
# 5
# 14
# 3.5
# 1

# %%
name = "Areesha"
age=19
college = "GEC"
print("My name is",name)
print("I am ",age,"year old")
print("My college is",college)
# Out:
# My name is Areesha
# I am  19 year old
# My college is GEC

# %%
name=input("Enter your name")
age=input("Enter your age")
city=input("Enter your city")
print("Hello",name)
print("You are",age,"year old")
print("you live in",city)
# Out:
# Hello Areesha
# You are 19 year old
# you live in Jabalpur

# %%
number = int(input("Enter number"))
if number > 0 :
    print("positive")
else :
    print("Nagetive")
# Out:
# Nagetive

# %%
marks = int(input("Enter number"))
if marks >=40 :
    print("Pass")
else :
    print("Fail")
# Out:
# Pass

# %%
age = int(input("Enter number"))
if age<18 :
    print("child")
elif age>=18 and age<60:
    print(" Adult")
else : print("Senior")
# Out:
# Senior

# %%
number = int(input("Enter number"))
if number %2==0 :
    print("even")
else :
    print("Odd")
# Out:
# Odd

# %%
number = int(input("Enter number"))
if number>0 :
    print("Positive")
elif number < 0:
    print("Nagetive")
else: 
    print("Zero")
# Out:
# Zero

# %%
number1 = int(input("Enter number"))
number2= int(input("Enter number"))
if number1 >= number2 :
    print("number1 is largest")
else : print("number2 is largest")
# Out:
# number1 is largest

# %%
number = int(input("Enter number"))
if number%3==0 and number%5==0 :
    print("divisible by both 3 and 5")
else : print("not divisible by 3 and 5")
# Out:
# not divisible bi 3 and 5

# %%
number1 = int(input("Enter number"))
number2= int(input("Enter number"))
operator=input("Enter operator(+,-,*,/):")
print("number 1 is", number1)
print("number 2 is", number2)
if operator == "+":
    print("result", number1+number2)
elif operator=="-" :
    print("result", number1-number2)
elif operator=="*" :
    print("result", number1*number2)
elif operator=="/" :
    print("result", number1/number2)
# Out:
# number 1 is 5
# number 2 is 5
# result 25

# %%
password =input("Enter number")
username = input("Enter number")
if password == "123" and username=="Admin" :
    print("Login successfully")
else :
    print("Invalid")
# Out:
# Login successfully
