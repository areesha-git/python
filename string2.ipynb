# %%
x ="Hello evevryone lets learn python"
x=x.split()
x.reverse()
x=" ".join(x)
print(x)

# %%
# olleh enoyreve stel nrael nothyp
x ="Hello evevryone lets learn python"
res=""
for i in x.split():
    res+=i[::-1]+" "
print(res.strip().lower())

# %%
x = "Python is awesome"
x=x.replace(" ","-")
print(x)

# %%
x ="hello world from python"
x=x.split().capitalize(x)
print(x)

# %%
x="hello world from python"

x=x.split()
x.reverse()
x=" ".join(x)
print(x)

# %%
x="programmimng"
res=[]
for i in x:
    res.append(i)
print(res)

# %%
x="Hello@world123"
res=""
for i in x:
    if i.isalnum():
      res+=i
print(res)
